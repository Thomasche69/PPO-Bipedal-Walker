# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import gymnasium as gym
import optuna
import torch.nn as nn

# %%
env = DummyVecEnv([lambda: gym.make("BipedalWalker-v3") for _ in range(32)])

# %%
# Initialize the PPO agent with the environment
model = PPO(
    policy="MlpPolicy",  # Multi-layer perceptron policy
    env=env,             # Environment
    verbose=1,           # Logging level
    learning_rate= 3e-4,  # Learning rate
    gamma=0.999,          # Discount factor
    n_steps=2048,        # Number of steps to run for each environment per update
    batch_size=64,       # Mini-batch size
    gae_lambda=0.95,         # lambda
    ent_coef=0.0,
    clip_range= 0.18,
    n_epochs= 10,
)

# Train the agent
model.learn(total_timesteps=5000000)  # Train for 1,500,000 steps

# Save the model
model.save("ppo_bipedal_best")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.4     |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    fps             | 3670     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 2507         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0051386817 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | -0.00403     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 258          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00802     |
# |    std                  | 0.999        |
# |    value_loss           | 457          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 2347        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011244737 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.658       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.998       |
# |    value_loss           | 1.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 418          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 2241         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0056392606 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 88           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00425     |
# |    std                  | 0.999        |
# |    value_loss           | 69.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 461         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 2169        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008624396 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00463    |
# |    std                  | 0.999       |
# |    value_loss           | 30.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 476         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 2150        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008724565 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00826    |
# |    std                  | 0.991       |
# |    value_loss           | 27.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 546         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 2118        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007078777 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00492    |
# |    std                  | 0.991       |
# |    value_loss           | 52.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 585        |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 2107       |
# |    iterations           | 8          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00796012 |
# |    clip_fraction        | 0.0742     |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -5.63      |
# |    explained_variance   | 0.596      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.974      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0081    |
# |    std                  | 0.986      |
# |    value_loss           | 28.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 566         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 2061        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009972814 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | -0.426      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.117       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.963       |
# |    value_loss           | 0.452       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 567          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 2062         |
# |    iterations           | 10           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0036649061 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57           |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00644     |
# |    std                  | 0.964        |
# |    value_loss           | 62.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 625          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 2056         |
# |    iterations           | 11           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0054859444 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.8         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00518     |
# |    std                  | 0.965        |
# |    value_loss           | 44.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 651         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 2044        |
# |    iterations           | 12          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007662661 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | -0.201      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.211       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00901    |
# |    std                  | 0.952       |
# |    value_loss           | 0.91        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 676          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 2039         |
# |    iterations           | 13           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0106750205 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -5.44        |
# |    explained_variance   | -0.0783      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0547       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00867     |
# |    std                  | 0.937        |
# |    value_loss           | 0.296        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 700         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 2040        |
# |    iterations           | 14          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007310817 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.923       |
# |    value_loss           | 0.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 744         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 2041        |
# |    iterations           | 15          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009572947 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | -0.159      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00927    |
# |    std                  | 0.906       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 764         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 2045        |
# |    iterations           | 16          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008051713 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0708      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00966    |
# |    std                  | 0.892       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 767          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 2053         |
# |    iterations           | 17           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0081310235 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -5.18        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0459       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00812     |
# |    std                  | 0.879        |
# |    value_loss           | 0.125        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 786          |
# |    ep_rew_mean          | -104         |
# | time/                   |              |
# |    fps                  | 2060         |
# |    iterations           | 18           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0046809027 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -5.15        |
# |    explained_variance   | 0.0542       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.177        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00395     |
# |    std                  | 0.877        |
# |    value_loss           | 27.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 804         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 2066        |
# |    iterations           | 19          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008026252 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0677      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.858       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 821         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 2070        |
# |    iterations           | 20          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004709997 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00636    |
# |    std                  | 0.857       |
# |    value_loss           | 12.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 2076        |
# |    iterations           | 21          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010253941 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | -0.35       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0176      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.844       |
# |    value_loss           | 0.181       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 866        |
# |    ep_rew_mean          | -101       |
# | time/                   |            |
# |    fps                  | 2081       |
# |    iterations           | 22         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00798094 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -4.98      |
# |    explained_variance   | 0.0446     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0144     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00814   |
# |    std                  | 0.841      |
# |    value_loss           | 0.0991     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | -100         |
# | time/                   |              |
# |    fps                  | 2083         |
# |    iterations           | 23           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0096821245 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0187       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0131      |
# |    std                  | 0.837        |
# |    value_loss           | 0.126        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | -99.5       |
# | time/                   |             |
# |    fps                  | 2086        |
# |    iterations           | 24          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008393888 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.016       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00837    |
# |    std                  | 0.828       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 906         |
# |    ep_rew_mean          | -98.9       |
# | time/                   |             |
# |    fps                  | 2090        |
# |    iterations           | 25          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008246404 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0681      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.818       |
# |    value_loss           | 0.153       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | -97.6       |
# | time/                   |             |
# |    fps                  | 2095        |
# |    iterations           | 26          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008617309 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.85       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0502      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.81        |
# |    value_loss           | 0.135       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 914        |
# |    ep_rew_mean          | -97.2      |
# | time/                   |            |
# |    fps                  | 2094       |
# |    iterations           | 27         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00812294 |
# |    clip_fraction        | 0.0635     |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -4.83      |
# |    explained_variance   | 0.342      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.8       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00613   |
# |    std                  | 0.809      |
# |    value_loss           | 11.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 925          |
# |    ep_rew_mean          | -96.6        |
# | time/                   |              |
# |    fps                  | 2095         |
# |    iterations           | 28           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0051056244 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.82        |
# |    explained_variance   | -0.641       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21           |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00323     |
# |    std                  | 0.806        |
# |    value_loss           | 28.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 936        |
# |    ep_rew_mean          | -95.8      |
# | time/                   |            |
# |    fps                  | 2098       |
# |    iterations           | 29         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00817306 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -4.79      |
# |    explained_variance   | 0.235      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0278     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00953   |
# |    std                  | 0.799      |
# |    value_loss           | 0.212      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | -94.4        |
# | time/                   |              |
# |    fps                  | 2099         |
# |    iterations           | 30           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0075362925 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.75        |
# |    explained_variance   | 0.485        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.088        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00939     |
# |    std                  | 0.788        |
# |    value_loss           | 0.144        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 953         |
# |    ep_rew_mean          | -93.9       |
# | time/                   |             |
# |    fps                  | 2102        |
# |    iterations           | 31          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009869015 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.778       |
# |    value_loss           | 0.147       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 962          |
# |    ep_rew_mean          | -93.1        |
# | time/                   |              |
# |    fps                  | 2104         |
# |    iterations           | 32           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0056295265 |
# |    clip_fraction        | 0.0761       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.67        |
# |    explained_variance   | -0.0727      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00719     |
# |    std                  | 0.779        |
# |    value_loss           | 32.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 938          |
# |    ep_rew_mean          | -93.5        |
# | time/                   |              |
# |    fps                  | 2104         |
# |    iterations           | 33           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0072456715 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.65        |
# |    explained_variance   | -0.297       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.104        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00795     |
# |    std                  | 0.77         |
# |    value_loss           | 0.366        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 936         |
# |    ep_rew_mean          | -93         |
# | time/                   |             |
# |    fps                  | 2103        |
# |    iterations           | 34          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.003926459 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00622    |
# |    std                  | 0.77        |
# |    value_loss           | 35.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 944          |
# |    ep_rew_mean          | -92.4        |
# | time/                   |              |
# |    fps                  | 2100         |
# |    iterations           | 35           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0061036823 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.161        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00593     |
# |    std                  | 0.77         |
# |    value_loss           | 7.36         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 953        |
# |    ep_rew_mean          | -91.8      |
# | time/                   |            |
# |    fps                  | 2099       |
# |    iterations           | 36         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00812065 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -4.62      |
# |    explained_variance   | 0.059      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0272     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00902   |
# |    std                  | 0.765      |
# |    value_loss           | 0.173      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | -90.5       |
# | time/                   |             |
# |    fps                  | 2101        |
# |    iterations           | 37          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009474561 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0351      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.761       |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | -89.6       |
# | time/                   |             |
# |    fps                  | 2103        |
# |    iterations           | 38          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008664949 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0664      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.753       |
# |    value_loss           | 0.201       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | -88.8       |
# | time/                   |             |
# |    fps                  | 2104        |
# |    iterations           | 39          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009339105 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0774      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.741       |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 993         |
# |    ep_rew_mean          | -87.8       |
# | time/                   |             |
# |    fps                  | 2105        |
# |    iterations           | 40          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009857954 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.728       |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -85.8       |
# | time/                   |             |
# |    fps                  | 2104        |
# |    iterations           | 41          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012529646 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.719       |
# |    value_loss           | 0.322       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -84.7       |
# | time/                   |             |
# |    fps                  | 2107        |
# |    iterations           | 42          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008469209 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.703       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00656    |
# |    std                  | 0.72        |
# |    value_loss           | 5.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -83.7       |
# | time/                   |             |
# |    fps                  | 2106        |
# |    iterations           | 43          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008472016 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0868      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.713       |
# |    value_loss           | 0.407       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -82.3       |
# | time/                   |             |
# |    fps                  | 2106        |
# |    iterations           | 44          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008779356 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.707       |
# |    value_loss           | 0.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -81         |
# | time/                   |             |
# |    fps                  | 2108        |
# |    iterations           | 45          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008276731 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.208       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.699       |
# |    value_loss           | 0.524       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -80          |
# | time/                   |              |
# |    fps                  | 2110         |
# |    iterations           | 46           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0064115953 |
# |    clip_fraction        | 0.056        |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.76         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.94         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00552     |
# |    std                  | 0.7          |
# |    value_loss           | 15.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+03     |
# |    ep_rew_mean          | -78.8        |
# | time/                   |              |
# |    fps                  | 2112         |
# |    iterations           | 47           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0056414395 |
# |    clip_fraction        | 0.0749       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.1         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00693     |
# |    std                  | 0.701        |
# |    value_loss           | 40.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -76.3       |
# | time/                   |             |
# |    fps                  | 2113        |
# |    iterations           | 48          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009932278 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.231       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.699       |
# |    value_loss           | 0.518       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -75.3       |
# | time/                   |             |
# |    fps                  | 2115        |
# |    iterations           | 49          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010098113 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.692       |
# |    value_loss           | 0.493       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+03     |
# |    ep_rew_mean          | -73.9        |
# | time/                   |              |
# |    fps                  | 2116         |
# |    iterations           | 50           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0073630325 |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00668     |
# |    std                  | 0.692        |
# |    value_loss           | 7.24         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -72.5       |
# | time/                   |             |
# |    fps                  | 2118        |
# |    iterations           | 51          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010772122 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.352       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.681       |
# |    value_loss           | 0.808       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 2119        |
# |    iterations           | 52          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010066291 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.674       |
# |    value_loss           | 0.634       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -67.1       |
# ...
# |    entropy_loss         | -3.7       |
# |    explained_variance   | -0.015     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 108        |
# |    n_updates            | 24240      |
# |    policy_gradient_loss | -0.014     |
# |    std                  | 0.625      |
# |    value_loss           | 127        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.11e+03   |
# |    ep_rew_mean          | 202        |
# | time/                   |            |
# |    fps                  | 1918       |
# |    iterations           | 2426       |
# |    time_elapsed         | 2589       |
# |    total_timesteps      | 4968448    |
# | train/                  |            |
# |    approx_kl            | 0.01782571 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | -0.0297    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 171        |
# |    n_updates            | 24250      |
# |    policy_gradient_loss | -0.0142    |
# |    std                  | 0.628      |
# |    value_loss           | 134        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 1918        |
# |    iterations           | 2427        |
# |    time_elapsed         | 2590        |
# |    total_timesteps      | 4970496     |
# | train/                  |             |
# |    approx_kl            | 0.023025375 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | -0.00484    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.7        |
# |    n_updates            | 24260       |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.625       |
# |    value_loss           | 67.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 1918        |
# |    iterations           | 2428        |
# |    time_elapsed         | 2592        |
# |    total_timesteps      | 4972544     |
# | train/                  |             |
# |    approx_kl            | 0.010265871 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.034       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 24270       |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.624       |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2429        |
# |    time_elapsed         | 2593        |
# |    total_timesteps      | 4974592     |
# | train/                  |             |
# |    approx_kl            | 0.013957432 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.0369      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.04        |
# |    n_updates            | 24280       |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.624       |
# |    value_loss           | 135         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.1e+03    |
# |    ep_rew_mean          | 202        |
# | time/                   |            |
# |    fps                  | 1917       |
# |    iterations           | 2430       |
# |    time_elapsed         | 2594       |
# |    total_timesteps      | 4976640    |
# | train/                  |            |
# |    approx_kl            | 0.02252839 |
# |    clip_fraction        | 0.303      |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -3.69      |
# |    explained_variance   | -0.0249    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.39       |
# |    n_updates            | 24290      |
# |    policy_gradient_loss | -0.0136    |
# |    std                  | 0.623      |
# |    value_loss           | 71.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 209         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2431        |
# |    time_elapsed         | 2595        |
# |    total_timesteps      | 4978688     |
# | train/                  |             |
# |    approx_kl            | 0.017586205 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.0391      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 24300       |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.624       |
# |    value_loss           | 137         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.12e+03   |
# |    ep_rew_mean          | 209        |
# | time/                   |            |
# |    fps                  | 1917       |
# |    iterations           | 2432       |
# |    time_elapsed         | 2596       |
# |    total_timesteps      | 4980736    |
# | train/                  |            |
# |    approx_kl            | 0.02136308 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | -0.0245    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.4        |
# |    n_updates            | 24310      |
# |    policy_gradient_loss | -0.0123    |
# |    std                  | 0.627      |
# |    value_loss           | 136        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 208         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2433        |
# |    time_elapsed         | 2597        |
# |    total_timesteps      | 4982784     |
# | train/                  |             |
# |    approx_kl            | 0.025262423 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.00124     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85        |
# |    n_updates            | 24320       |
# |    policy_gradient_loss | -0.00921    |
# |    std                  | 0.626       |
# |    value_loss           | 70          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2434        |
# |    time_elapsed         | 2599        |
# |    total_timesteps      | 4984832     |
# | train/                  |             |
# |    approx_kl            | 0.011665253 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.67        |
# |    n_updates            | 24330       |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.626       |
# |    value_loss           | 161         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2435        |
# |    time_elapsed         | 2600        |
# |    total_timesteps      | 4986880     |
# | train/                  |             |
# |    approx_kl            | 0.014199981 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 169         |
# |    n_updates            | 24340       |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.627       |
# |    value_loss           | 227         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2436        |
# |    time_elapsed         | 2601        |
# |    total_timesteps      | 4988928     |
# | train/                  |             |
# |    approx_kl            | 0.005709028 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 452         |
# |    n_updates            | 24350       |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.628       |
# |    value_loss           | 375         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2437        |
# |    time_elapsed         | 2602        |
# |    total_timesteps      | 4990976     |
# | train/                  |             |
# |    approx_kl            | 0.007973761 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | -0.274      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.2        |
# |    n_updates            | 24360       |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.628       |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2438        |
# |    time_elapsed         | 2603        |
# |    total_timesteps      | 4993024     |
# | train/                  |             |
# |    approx_kl            | 0.018001597 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.3        |
# |    n_updates            | 24370       |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.625       |
# |    value_loss           | 71.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2439        |
# |    time_elapsed         | 2604        |
# |    total_timesteps      | 4995072     |
# | train/                  |             |
# |    approx_kl            | 0.012791172 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | -0.0814     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 188         |
# |    n_updates            | 24380       |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.626       |
# |    value_loss           | 134         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 1917       |
# |    iterations           | 2440       |
# |    time_elapsed         | 2605       |
# |    total_timesteps      | 4997120    |
# | train/                  |            |
# |    approx_kl            | 0.01764039 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -3.72      |
# |    explained_variance   | 0.0499     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 113        |
# |    n_updates            | 24390      |
# |    policy_gradient_loss | -0.0138    |
# |    std                  | 0.627      |
# |    value_loss           | 131        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2441        |
# |    time_elapsed         | 2606        |
# |    total_timesteps      | 4999168     |
# | train/                  |             |
# |    approx_kl            | 0.018346768 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 24400       |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.627       |
# |    value_loss           | 207         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 2442        |
# |    time_elapsed         | 2607        |
# |    total_timesteps      | 5001216     |
# | train/                  |             |
# |    approx_kl            | 0.032658476 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.18        |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.0701      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 24410       |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.631       |
# |    value_loss           | 66.4        |
# -----------------------------------------

# %%
env = gym.make("BipedalWalker-v3")
model = PPO.load("ppo_bipedal_best", env = env)
env.reset()
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=30)
print(f"Mean Reward = {mean_reward}, Std Reward = {std_reward}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Mean Reward = 235.44227944483484, Std Reward = 95.43356145832836

# %%
from gymnasium.wrappers import RecordVideo
video_folder = "videosbipedal"  # Directory to save the video
env = gym.make("BipedalWalker-v3", render_mode="rgb_array")
env = RecordVideo(env, video_folder=video_folder, episode_trigger=lambda x: True)

model = PPO.load("ppo_bipedal_best", env=env)

# Test the trained agent
obs, info = env.reset()
done = False

while not done:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)

env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
